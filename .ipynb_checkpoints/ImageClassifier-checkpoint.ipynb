# %% [markdown]
# # Introduction: Building an Emotion Classifier with Convolutional Neural Networks
#
# In the vast spectrum of human emotions, the ability to recognize and understand facial expressions plays a crucial role in interpersonal communication and artificial intelligence. As we navigate the realms of computer vision, this project embarks on a journey to create an image classifier capable of discerning between happy, sad, and angry facial expressions.
#
# Harnessing the power of Convolutional Neural Networks (CNN), a class of deep neural networks well-suited for image-related tasks, we delve into the intricate details of facial features. The goal is to train a model that not only identifies emotions but does so with a high degree of accuracy, mirroring the nuanced nature of human expression.
#
# Before we unleash the capabilities of our neural network, we navigate the terrain of image preprocessing. This critical step involves transforming raw images into a format that optimally serves the learning process. From resizing and normalization to augmentation, each preprocessing technique contributes to enhancing the model's ability to generalize across various facial expressions.
#
# As we embark on this exciting endeavor, our journey will involve the exploration of labeled datasets, the design of a CNN architecture, and the iterative process of training and fine-tuning our model. Join us in unraveling the complexities of emotion recognition through the lens of deep learning, where pixels transform into emotions, and neural networks decode the language of the human face.
#
# Welcome to the realm of emotion-driven image classification — where technology meets empathy, and pixels pave the way for a more emotionally intelligent future.

# %%
import tensorflow as tf
import os # this is used to navigate file structure 
from matplotlib import pyplot as plt

# %%
os.listdir('data')
# Out:
# ['Angry', 'Happy', 'Sad']

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Avoid OOm errors by setting GPU Memory Consumption Growth
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# #### Preprocessing and cleaning

# %%
import cv2
import imghdr

# %%
data_dir = 'data' # the name where you have save your file in

# %%
image_exts = ['jpeg','jpg','bmp','png'] # so we can loop through

# %%
os.listdir(data_dir)
# Out:
# ['Angry', 'Happy', 'Sad']

# %%
# to get the list in a folder 
len(os.listdir(os.path.join(data_dir,'Sad')))

# also you can go ahead and clean the data on your own.
# Out:
# 186

# %%
img_ = cv2.imread(os.path.join(data_dir,'Sad','crying-at-work.jpg'))

# %%
img_.shape
# Out:
# (3412, 5126, 3)

# %% [markdown]
# ###### Here we can fully see that this is an RGB image.

# %%
plt.imshow(cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)) #this helps convert from BGR to RGB
plt.show()

# %%
for image_class in os.listdir(data_dir): # we are going through our directory -- data
    for image in os.listdir(os.path.join(data_dir, image_class)): #going throught all the images now.
        image_path = os.path.join(data_dir,image_class, image) # we are just looping through the path
        try:
            img = cv2.imread(image_path) #for image
            tip = imghdr.what(image_path) # for valid extention
            if tip not in image_exts: # checking images not with this ext
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path) # removes them
        except Exception as e:
            print('Issue with image {}'.fromat(image_path))

# %% [markdown]
# ### Loading in the data

# %%
tf.data.Dataset??
# Out:
# Init signature: tf.data.Dataset(variant_tensor)
# Source:
# @tf_export("data.Dataset", v1=[])
# @six.add_metaclass(abc.ABCMeta)
# class DatasetV2(collections_abc.Iterable, tracking_base.Trackable,
#                 composite_tensor.CompositeTensor):
#   """Represents a potentially large set of elements.
#
#   The `tf.data.Dataset` API supports writing descriptive and efficient input
#   pipelines. `Dataset` usage follows a common pattern:
#
#   1. Create a source dataset from your input data.
#   2. Apply dataset transformations to preprocess the data.
#   3. Iterate over the dataset and process the elements.
#
#   Iteration happens in a streaming fashion, so the full dataset does not need to
#   fit into memory.
#
#   Source Datasets:
#
#   The simplest way to create a dataset is to create it from a python `list`:
#
#   >>> dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
#   >>> for element in dataset:
#   ...   print(element)
#   tf.Tensor(1, shape=(), dtype=int32)
# ...

# %%
import numpy as np

# %%
data = tf.keras.utils.image_dataset_from_directory??
# Out:
# Signature:
# tf.keras.utils.image_dataset_from_directory(
#     directory,
#     labels='inferred',
#     label_mode='int',
#     class_names=None,
#     color_mode='rgb',
#     batch_size=32,
#     image_size=(256, 256),
#     shuffle=True,
#     seed=None,
#     validation_split=None,
#     subset=None,
#     interpolation='bilinear',
#     follow_links=False,
#     crop_to_aspect_ratio=False,
#     **kwargs,
# )
# Source:
# @keras_export('keras.utils.image_dataset_from_directory',
#               'keras.preprocessing.image_dataset_from_directory',
#               v1=[])
# def image_dataset_from_directory(directory,
#                                  labels='inferred',
#                                  label_mode='int',
#                                  class_names=None,
#                                  color_mode='rgb',
#                                  batch_size=32,
#                                  image_size=(256, 256),
#                                  shuffle=True,
# ...

# %%
data = tf.keras.utils.image_dataset_from_directory('data', 
                                                   batch_size=32) # building that data pipeline
# Out:
# Found 548 files belonging to 3 classes.

# %%
data.class_names
# Out:
# ['Angry', 'Happy', 'Sad']

# %%
data_iterator = data.as_numpy_iterator() # access the data pipline and looping through
data_iterator

# %%
batch = data_iterator.next()
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
batch[0]
# Out:
# array([[[[243.       , 244.       , 248.       ],
#          [243.       , 244.       , 248.       ],
#          [243.       , 244.       , 248.       ],
#          ...,
#          [216.       , 221.       , 227.       ],
#          [215.16797  , 220.16797  , 226.16797  ],
#          [212.       , 219.       , 225.       ]],
#
#         [[243.       , 244.       , 248.       ],
#          [243.       , 244.       , 248.       ],
#          [243.       , 244.       , 248.       ],
#          ...,
#          [216.       , 221.       , 225.84291  ],
#          [215.95288  , 220.95288  , 226.95288  ],
#          [212.       , 219.       , 225.       ]],
#
#         [[243.       , 244.       , 248.       ],
#          [243.       , 244.       , 248.       ],
#          [243.57227  , 244.57227  , 248.57227  ],
#          ...,
#          [216.       , 221.       , 225.77344  ],
#          [216.       , 221.       , 227.       ],
#          [213.       , 220.       , 226.       ]],
#
# ...

# %%
fig, ax = plt.subplots(ncols=4, figsize = (20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# - Here we can see happy = 1, sad = 2 and angry = 0

# %% [markdown]
# ## Scaling images

# %%
batch[0].min(), batch[0].max()
# Out:
# (0.0, 255.0)

# %%
data = data.map(lambda x,y: (x/255, y)) # scaling the data

# %%
scaled_iterator = data.as_numpy_iterator()
batch = scaled_iterator.next() # this is used to go to the next batch
batch[0].min(), batch[0].max()
# Out:
# (0.0, 1.0)

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
train_size +val_size +test_size
# Out:
# 18

# %%
len(data) # number of batches
# Out:
# 18

# %%
# Look into take, skip

# %% [markdown]
# ## CNN Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
opz = tf.optimizers.Adam(learning_rate=0.001) # this affected greatly

# %%
model.compile(optimizer= opz,
             loss= tf.losses.SparseCategoricalCrossentropy(),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 3)                 771
#
# ...
# Total params: 3,697,139
# Trainable params: 3,697,139
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Training
logdir = 'logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = logdir)

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
hist = model.fit(train,epochs=20, 
                 validation_data= val,
                 callbacks= [tensorboard_callback])
# Out:
# Epoch 1/20
# 12/12 [==============================] - 43s 3s/step - loss: 0.2413 - accuracy: 0.9245 - val_loss: 0.2574 - val_accuracy: 0.9141
# Epoch 2/20
# 12/12 [==============================] - 34s 2s/step - loss: 0.1557 - accuracy: 0.9531 - val_loss: 0.0995 - val_accuracy: 0.9688
# Epoch 3/20
# 12/12 [==============================] - 27s 2s/step - loss: 0.1199 - accuracy: 0.9661 - val_loss: 0.0869 - val_accuracy: 0.9844
# Epoch 4/20
# 12/12 [==============================] - 65s 5s/step - loss: 0.0598 - accuracy: 0.9948 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 5/20
# 12/12 [==============================] - 84s 5s/step - loss: 0.0479 - accuracy: 0.9818 - val_loss: 0.0413 - val_accuracy: 0.9922
# Epoch 6/20
# 12/12 [==============================] - 78s 5s/step - loss: 0.0370 - accuracy: 0.9974 - val_loss: 0.0249 - val_accuracy: 0.9922
# Epoch 7/20
# ...

# %%
# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

    # Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

    # Adjust layout for better visualization
plt.tight_layout()

    # Show the plots
plt.show()

# %%
last_epoch_results = {
        'last_epoch_train_loss': hist.history['loss'][-1],
        'last_epoch_val_loss': hist.history['val_loss'][-1],
        'last_epoch_train_accuracy': hist.history['accuracy'][-1],
        'last_epoch_val_accuracy': hist.history['val_accuracy'][-1],
    }

    # Print last epoch metrics
print("\nLast Epoch Metrics:")
print(f"Train Loss: {last_epoch_results['last_epoch_train_loss']:.4f}")
print(f"Validation Loss: {last_epoch_results['last_epoch_val_loss']:.4f}")
print(f"Train Accuracy: {last_epoch_results['last_epoch_train_accuracy']:.4f}")
print(f"Validation Accuracy: {last_epoch_results['last_epoch_val_accuracy']:.4f}")
# Out:
# Last Epoch Metrics:
# Train Loss: 0.0004
# Validation Loss: 0.0003
# Train Accuracy: 1.0000
# Validation Accuracy: 1.0000

# %% [markdown]
# ## Evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, CategoricalAccuracy
from tensorflow.keras.utils import to_categorical

precision = Precision()
recall = Recall()
accuracy = CategoricalAccuracy()

for batch in test.as_numpy_iterator():
    X, y = batch  # the y here is the true value label
    y_true_one_hot = to_categorical(y, num_classes=3)
    y_pred = model.predict(X)
    y_pred = y_pred.reshape(y.shape[0], 3)

    precision.update_state(y_true_one_hot, y_pred)
    recall.update_state(y_true_one_hot, y_pred)
    accuracy.update_state(y_true_one_hot, y_pred)

# %%
print(f'Precision:{precision.result().numpy()}, Recall:{recall.result().numpy()},Accuracy:{accuracy.result().numpy()}')
# Out:
# Precision:1.0, Recall:1.0,Accuracy:1.0

# %% [markdown]
# ## Test on data it has not seen before

# %%
test_happy = cv2.imread(os.path.join(data_dir,'happy_test.jpg'))
plt.imshow(cv2.cvtColor(test_happy, cv2.COLOR_BGR2RGB)) #this helps convert from BGR to RGB
pred_happy = model.predict(np.expand_dims(resize/255, 0))
predicted_class = np.argmax(pred_happy)
class_mapping = {0: 'angry', 1: 'happy', 2: 'sad'}
predicted_emotion = class_mapping[predicted_class]

print("Predicted emotion:", predicted_emotion)
# Out:
# Predicted emotion: happy

# %%
test_angry = cv2.imread(os.path.join(data_dir,'Angry_test.jpg'))
plt.imshow(cv2.cvtColor(test_angry, cv2.COLOR_BGR2RGB)) #this helps convert from BGR to RGB

resize = tf.image.resize(test_angry, (256,256))
plt.imshow(resize.numpy().astype(int))

pred_angry = model.predict(np.expand_dims(resize/255, 0))
predicted_class = np.argmax(pred_angry)
class_mapping = {0: 'angry', 1: 'happy', 2: 'sad'}
predicted_emotion = class_mapping[predicted_class]

print("Predicted emotion:", predicted_emotion)
plt.show()
# Out:
# Predicted emotion: angry

# %%
test_sad = cv2.imread(os.path.join(data_dir,'sad.jpg'))
plt.imshow(cv2.cvtColor(test_sad, cv2.COLOR_BGR2RGB)) #this helps convert from BGR to RGB
resize = tf.image.resize(test_sad, (256,256))
plt.imshow(resize.numpy().astype(int))

pred_sad = model.predict(np.expand_dims(resize/255, 0))
predicted_class = np.argmax(pred_sad)
class_mapping = {0: 'angry', 1: 'happy', 2: 'sad'}
predicted_emotion = class_mapping[predicted_class]

print("Predicted emotion:", predicted_emotion)
plt.show()
# Out:
# Predicted emotion: happy

# %% [markdown]
# ## Save model

# %%
from tensorflow.keras.models import load_model
model.save(os.path.join('Model','emotion_model.h5'))
